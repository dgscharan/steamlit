# %%
import cv2
import numpy as np 
import pytesseract
import easyocr
from matplotlib import pyplot as plt
import PIL
from PIL import ImageDraw

# %%
reader = easyocr.Reader(['en'], gpu=True)

# %%
im = PIL.Image.open('./1_2.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1654x2339 at 0x201498A9160>

# %%
# %time

bounds = reader.readtext('./2.jpg', batch_size=1)
bounds
# Out:
# Wall time: 0 ns
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-37b13a199177> in <module>
#       1 get_ipython().run_line_magic('time', '')
#       2
# ----> 3 bounds = reader.readtext('./2.jpg', batch_size=1)
#       4 bounds
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\easyocr\easyocr.py in readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, add_margin)
#     364                                                  slope_ths, ycenter_ths,\
#     365                                                  height_ths,width_ths,\
# --> 366                                                  add_margin, False)
#     367
#     368         result = self.recognize(img_cv_grey, horizontal_list, free_list,\
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\easyocr\easyocr.py in detect(self, img, min_size, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, add_margin, reformat)
#     287         text_box = get_textbox(self.detector, img, canvas_size, mag_ratio,\
#     288                                text_threshold, link_threshold, low_text,\
# --> 289                                False, self.device)
#     290         horizontal_list, free_list = group_text_box(text_box, slope_ths,\
#     291                                                     ycenter_ths, height_ths,\
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\easyocr\detection.py in get_textbox(detector, image, canvas_size, mag_ratio, text_threshold, link_threshold, low_text, poly, device)
#      68 def get_textbox(detector, image, canvas_size, mag_ratio, text_threshold, link_threshold, low_text, poly, device):
#      69     result = []
# ---> 70     bboxes, polys = test_net(canvas_size, mag_ratio, detector, image, text_threshold, link_threshold, low_text, poly, device)
#      71
#      72     for i, box in enumerate(polys):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\easyocr\detection.py in test_net(canvas_size, mag_ratio, net, image, text_threshold, link_threshold, low_text, poly, device)
#      36     # forward pass
#      37     with torch.no_grad():
# ---> 38         y, feature = net(x)
#      39
#      40     # make score and link map
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\parallel\data_parallel.py in forward(self, *inputs, **kwargs)
#     157         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
#     158         if len(self.device_ids) == 1:
# --> 159             return self.module(*inputs[0], **kwargs[0])
#     160         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     161         outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\easyocr\craft.py in forward(self, x)
#      58     def forward(self, x):
#      59         """ Base network """
# ---> 60         sources = self.basenet(x)
#      61
#      62         """ U network """
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\easyocr\modules.py in forward(self, X)
#      59
#      60     def forward(self, X):
# ---> 61         h = self.slice1(X)
#      62         h_relu2_2 = h
#      63         h = self.slice2(h)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
# --> 423         return self._conv_forward(input, self.weight)
#     424
#     425 class Conv3d(_ConvNd):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight)
#     418                             _pair(0), self.dilation, self.groups)
#     419         return F.conv2d(input, weight, self.bias, self.stride,
# --> 420                         self.padding, self.dilation, self.groups)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: CUDA out of memory. Tried to allocate 1.15 GiB (GPU 0; 4.00 GiB total capacity; 2.52 GiB already allocated; 178.61 MiB free; 2.68 GiB reserved in total by PyTorch)

# %%
def draw_boxes(image, bounds, color = "red", width = 4):
    draw  = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill = color, width = width)
    return image

draw_boxes(im, bounds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-13eaf0548327> in <module>
#       6     return image
#       7
# ----> 8 draw_boxes(im, bounds)
#
# <ipython-input-13-13eaf0548327> in draw_boxes(image, bounds, color, width)
#       3     for bound in bounds:
#       4         p0, p1, p2, p3 = bound[0]
# ----> 5         draw.line([*p0, *p1, *p2, *p3, *p0], fill = color, width = width)
#       6     return image
#       7
#
# TypeError: 'numpy.int32' object is not iterable
